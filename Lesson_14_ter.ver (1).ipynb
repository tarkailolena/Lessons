# %%
# 1. 24360
# 2. 1024
# 3. 80
# 5. 5040
# 6. 3024
# 7. 120
# 8. 2002
# 9. 10
# 10. 56
# 11. 1087568040
# 12. 210

# %%
# 1. 5/42
# 2. 280
# 3. 0.022344
# 4. 0.8848

# %%
# 1. 11/21
# 2. 
# 3. 1/2
