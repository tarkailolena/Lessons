# %%
import pandas as pd
import numpy as np
import ast
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics.pairwise import linear_kernel
from tabulate import tabulate

# %%
meta = pd.read_csv('movies_metadata.csv', low_memory=False)
keywords = pd.read_csv('keywords.csv')
credits = pd.read_csv('credits.csv')

# %%
meta['id'] = pd.to_numeric(meta['id'], errors='coerce').fillna(0).astype(int)
keywords['id'] = keywords['id'].astype(int)
credits['id'] = credits['id'].astype(int)

# %%
df = meta.merge(keywords, on='id').merge(credits, on='id')

# %%
df = df.sort_values('popularity', ascending=False).head(5000).reset_index(drop=True)

# %%
def get_list(x):
    try:
        if isinstance(x, str):
            names = [i['name'] for i in ast.literal_eval(x)]
            return names[:3]
    except: return []
    return []

df['genres_list'] = df['genres'].apply(get_list)
df['cast_list'] = df['cast'].apply(get_list)
df['genres_display'] = df['genres_list'].apply(lambda x: ', '.join(x) if x else 'Other')

# %%
def create_soup(x):
    gen = ' '.join([i.lower().replace(" ","") for i in x['genres_list']])
    cast = ' '.join([i.lower().replace(" ","") for i in x['cast_list']])
    desc = str(x['overview']).lower()
    return f"{gen} {cast} {desc}"

df['metadata_soup'] = df.apply(create_soup, axis=1)

# %%
tfidf = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf.fit_transform(df['metadata_soup'])

kmeans = KMeans(n_clusters=30, random_state=42, n_init=10)
df['cluster_id'] = kmeans.fit_predict(tfidf_matrix)

# %%
clusters = df.groupby('cluster_id')['title'].apply(lambda x: ', '.join(x.head(5))).reset_index()
clusters['count'] = df.groupby('cluster_id')['title'].count().values
clusters.columns = ['ID кластера', 'Примеры фильмов', 'Всего фильмов']
print(tabulate(clusters[['ID кластера', 'Всего фильмов', 'Примеры фильмов']], 
               headers='keys', tablefmt='grid', showindex=False))
# Out:
# +---------------+-----------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   ID кластера |   Всего фильмов | Примеры фильмов                                                                                                                                                                                                                 |
# +===============+=================+=================================================================================================================================================================================================================================+
# |             0 |             117 | Me, Myself & Irene, Analyze That, The Aviator, The X Files: I Want to Believe, Kramer vs. Kramer                                                                                                                                |
# +---------------+-----------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |             1 |             448 | The Mexican, Armored, The Life of David Gale, Perfect Stranger, White House Down                                                                                                                                                |
# +---------------+-----------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |             2 |              95 | Angels with Dirty Faces, Little Women, White Squall, Bronson, Hoop Dreams                                                                                                                                                       |
# +---------------+-----------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |             3 |             482 | The Last Kiss, 4 Months, 3 Weeks and 2 Days, In & Out, Great Expectations, Elles                                                                                                                                                |
# +---------------+-----------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |             4 |             234 | Jarhead, Uncommon Valor, Charlie Wilson's War, The Next Karate Kid, Foreign Correspondent                                                                                                                                       |
# +---------------+-----------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |             5 |              97 | Original Sin, The Naked Gun 2½: The Smell of Fear, Fright Night, Charlie Countryman, George of the Jungle                                                                                                                       |
# +---------------+-----------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |             6 |               8 | Le Samouraï, Le Samouraï, Le Samouraï, Le Samouraï, Le Samouraï                                                                                                                                                                 |
# +---------------+-----------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |             7 |             247 | Dinosaur, Shaun the Sheep Movie, The Summer I Turned 15, The Substitute, Flushed Away                                                                                                                                           |
# +---------------+-----------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |             8 |              75 | What Women Want, Seems Like Old Times, Horrible Bosses, Wall Street: Money Never Sleeps, Iron Jawed Angels                                                                                                                      |
# +---------------+-----------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |             9 |              77 | The Medallion, Wake of Death, Hero, The Art of War, Starman                                                                                                                                                                     |
# +---------------+-----------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |            10 |             109 | Leaves of Grass, 30 Minutes or Less, Layer Cake, The Onion Field, Duck, You Sucker                                                                                                                                              |
# +---------------+-----------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |            11 |               8 | Pokémon 4Ever: Celebi - Voice of the Forest, Pokémon 4Ever: Celebi - Voice of the Forest, Pokémon 4Ever: Celebi - Voice of the Forest, Pokémon 4Ever: Celebi - Voice of the Forest, Pokémon 4Ever: Celebi - Voice of the Forest |
# +---------------+-----------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |            12 |             165 | All the Boys Love Mandy Lane, Ride Along, Clueless, Project X, Paper Towns                                                                                                                                                      |
# +---------------+-----------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |            13 |             174 | Christopher and His Kind, The Conformist, Pretty Persuasion, Kicking & Screaming, The Pool Boys                                                                                                                                 |
# +---------------+-----------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |            14 |             270 | Chameli Ki Shaadi, Me casé con un boludo, The Double Lover, Laura, Notting Hill                                                                                                                                                 |
# +---------------+-----------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |            15 |             125 | Dream House, Happy Accidents, Sea of Love, Immortal, Take Me Home                                                                                                                                                               |
# +---------------+-----------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |            16 |             215 | Hollywood Ending, Down and Out in Beverly Hills, Bad Grandpa .5, His Girl Friday, Porn in the Hood                                                                                                                              |
# +---------------+-----------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |            17 |              89 | Arena, Dumb and Dumber, Charlie's Angels, The Colony, Swordfish                                                                                                                                                                 |
# +---------------+-----------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |            18 |             121 | Cliffhanger, The Abyss, The Black Cauldron, Leatherface, Rapture-Palooza                                                                                                                                                        |
# +---------------+-----------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |            19 |              67 | High Plains Drifter, Station West, The Hallelujah Trail, They Call Me Trinity, Tall in the Saddle                                                                                                                               |
# +---------------+-----------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |            20 |             141 | Alvin and the Chipmunks: The Squeakquel, Flashdance, Get Rich or Die Tryin', All Eyez on Me, In the Bedroom                                                                                                                     |
# +---------------+-----------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |            21 |             446 | The Lords of Salem, Critters 2, The Lair of the White Worm, The Fog, American Mary                                                                                                                                              |
# +---------------+-----------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |            22 |             488 | Blade Runner, Black Dawn, Black Sea, Cries and Whispers, Brainstorm                                                                                                                                                             |
# +---------------+-----------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |            23 |              93 | Baraka, Project Nim, Caesar Must Die, Pelota, The Captains                                                                                                                                                                      |
# +---------------+-----------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |            24 |             123 | Lymelife, Vexille, Hack!, Gamer, No Escape                                                                                                                                                                                      |
# +---------------+-----------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |            25 |             234 | Hamlet, Eyes Without a Face, Willow, Neighbors 2: Sorority Rising, Homefront                                                                                                                                                    |
# +---------------+-----------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |            26 |              75 | The Haunting of Molly Hartley, The Devil's Candy, The Devil's Candy, Sightseers, Goal!: The Dream Begins                                                                                                                        |
# +---------------+-----------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |            27 |              70 | El Mariachi, A Dangerous Method, The Girl with the Dragon Tattoo, Scooby-Doo! Curse of the Lake Monster, The Hunt for the BTK Killer                                                                                            |
# +---------------+-----------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |            28 |              95 | Hyper Sapien: People from Another Star, A Dog's Purpose, Krull, Enemy Mine, Scooby-Doo! The Mystery Begins                                                                                                                      |
# +---------------+-----------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |            29 |              12 | The Congress, The Congress, The Congress, The Congress, The Congress                                                                                                                                                            |
# +---------------+-----------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+

# %%
def recommend_me(movie_name):
    search = movie_name.lower().strip()
    df['title_lower'] = df['title'].str.lower()
    
    if search not in df['title_lower'].values:
        suggestion = df[df['title_lower'].str.contains(m_search, na=False)]['title'].head(3).tolist()
        return f"Фильм '{movie_name}' не найден. Возможно, вы имели в виду: {suggestion}"
    
    movie_row = df[df['title_lower'] == search].iloc[0]
    cluster = movie_row['cluster_id']
    
    recommendations = df[df['cluster_id'] == cluster][['title', 'genres_display']].head(10)
    recommendations = recommendations[recommendations['title'].str.lower() != search].head(6)
    
    recommendations.columns = ['Название фильма', 'Жанры']
    print(f"Фильм: {movie_row['title']} (Кластер №{cluster})")
    print(f"Похожие фильмы :")
    
    return tabulate(recommendations, headers='keys', tablefmt='grid', showindex=False)

print(recommend_me('Toy Story That Time Forgot'))
# Out:
# Фильм: Toy Story That Time Forgot (Кластер №7)
# Похожие фильмы :
# +------------------------+------------------------------+
# | Название фильма        | Жанры                        |
# +========================+==============================+
# | Dinosaur               | Animation, Family            |
# +------------------------+------------------------------+
# | Shaun the Sheep Movie  | Family, Animation, Comedy    |
# +------------------------+------------------------------+
# | The Summer I Turned 15 | Drama                        |
# +------------------------+------------------------------+
# | The Substitute         | Thriller, Comedy             |
# +------------------------+------------------------------+
# | Flushed Away           | Adventure, Animation, Comedy |
# +------------------------+------------------------------+
# | Small Fry              | Animation, Family            |
# +------------------------+------------------------------+
